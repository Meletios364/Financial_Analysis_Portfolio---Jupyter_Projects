# %% [markdown]
# ## Data Analytics 1st Lab Session

# %% [markdown]
# ### 1.Open the video game sales file using pandas. Check characteristics of the dataset. What is the shape of the dataset, what are the statistics of the columns, are there any NaNs?

# %%
import pandas as pd

# %%
ml1 = pd.read_csv('C:/Users/lioul/Downloads/vgsales.csv')

# %%
ml1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
nan_count = ml1.isna().sum()

# %%
nan_count
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
#Check characteristics of the dataset
ml1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
#What is the shape of the dataset
ml1.shape
# Out:
# (16598, 11)

# %% [markdown]
# ### 2.Clean the dataset (if you find any NaNs)

# %%
ml1.dropna()
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ml1.dropna(axis=0, inplace=True)
ml1original = ml1.copy()

# %%
ml1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### 3.Which game has the highest global sales? What is its platform?

# %%
ml1_high = ml1.groupby('Global_Sales').max()

# %%
ml1_high.tail(1)
# Out:
#               Rank        Name Platform    Year   Genre Publisher  NA_Sales  \
# Global_Sales
# 82.74            1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49
#
#               EU_Sales  JP_Sales  Other_Sales
# Global_Sales
# 82.74            29.02      3.77         8.46

# %% [markdown]
# ### 4.Which are the platforms in the dataset?

# %%
ml1['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# ### 5.Which are the top ten selling games for PS4 (Global sales)? Is this the same for Europe and Japan sales combined?

# %%
ml1.sort_values(['Global_Sales'], ascending = False).head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
ml2 = ml1[(ml1["Platform"]=="PS4")]

# %%
ml2.head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 154   155                         Destiny      PS4  2014.0       Shooter
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 236   237                  The Last of Us      PS4  2014.0        Action
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# ...

# %%
ml2['eu_jp_sales'] = ml2['EU_Sales']+ml2['JP_Sales'].head(10)
# Out:
# C:\Users\lioul\AppData\Local\Temp\ipykernel_18120\3746655513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml2['eu_jp_sales'] = ml2['EU_Sales']+ml2['JP_Sales'].head(10)

# %%
ml2.head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 154   155                         Destiny      PS4  2014.0       Shooter
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 236   237                  The Last of Us      PS4  2014.0        Action
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# ...

# %% [markdown]
# ### 6.How many games were released for XOne in 2016? Which was the top selling in Europe?

# %%
ml1 = ml1[(ml1["Platform"]=="XOne") & (ml1["Year"]==2016)]

# %%
ml1
# Out:
#         Rank                                               Name Platform  \
# 845      847                          Tom Clancy's The Division     XOne
# 1224    1226                                            FIFA 17     XOne
# 2434    2436                                    Far Cry: Primal     XOne
# 2444    2446                                          Overwatch     XOne
# 2505    2507                                      Madden NFL 17     XOne
# 2991    2993                                        Doom (2016)     XOne
# 3145    3147                                           NBA 2K17     XOne
# 3927    3929                                      Quantum Break     XOne
# 4430    4432               Plants vs. Zombies: Garden Warfare 2     XOne
# 4820    4822                                    EA Sports UFC 2     XOne
# 5015    5017                                    Forza Horizon 3     XOne
# 5268    5270                                     Dark Souls III     XOne
# ...

# %%
ml1.sort_values(['EU_Sales'], ascending = False).head(1)
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 1224  1226  FIFA 17     XOne  2016.0  Sports  Electronic Arts      0.17
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1224      1.26       0.0          0.1          1.53

# %% [markdown]
# ### 7.Replace where XOne with ‘X Box One’

# %%
ml1['Platform'].replace({'XOne':'X Box One'}, inplace = True)
# Out:
# C:\Users\lioul\AppData\Local\Temp\ipykernel_18120\659574336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml1['Platform'].replace({'XOne':'X Box One'}, inplace = True)

# %%
ml1
# Out:
#         Rank                                               Name   Platform  \
# 845      847                          Tom Clancy's The Division  X Box One
# 1224    1226                                            FIFA 17  X Box One
# 2434    2436                                    Far Cry: Primal  X Box One
# 2444    2446                                          Overwatch  X Box One
# 2505    2507                                      Madden NFL 17  X Box One
# 2991    2993                                        Doom (2016)  X Box One
# 3145    3147                                           NBA 2K17  X Box One
# 3927    3929                                      Quantum Break  X Box One
# 4430    4432               Plants vs. Zombies: Garden Warfare 2  X Box One
# 4820    4822                                    EA Sports UFC 2  X Box One
# 5015    5017                                    Forza Horizon 3  X Box One
# ...

# %% [markdown]
# ### 8.How many PC games have higher sales than 3 million global sales?

# %%
ml1.describe()
# Out:
#                Rank    Year   NA_Sales   EU_Sales   JP_Sales  Other_Sales  \
# count     54.000000    54.0  54.000000  54.000000  54.000000    54.000000
# mean   10824.962963  2016.0   0.123889   0.085741   0.000185     0.019444
# std     4976.662328     0.0   0.217085   0.193611   0.001361     0.033782
# min      847.000000  2016.0   0.000000   0.000000   0.000000     0.000000
# 25%     6347.250000  2016.0   0.010000   0.010000   0.000000     0.000000
# 50%    12193.000000  2016.0   0.030000   0.020000   0.000000     0.005000
# 75%    15020.250000  2016.0   0.145000   0.077500   0.000000     0.027500
# max    16579.000000  2016.0   1.200000   1.260000   0.010000     0.180000
#
#        Global_Sales
# count     54.000000
# mean       0.229074
# std        0.384753
# min        0.010000
# 25%        0.020000
# 50%        0.065000
# 75%        0.270000
# max        2.010000

# %%
ml1original
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ml1original_high = ml1original[ml1original['Global_Sales'] > 3.00]

# %%
ml1original_high.shape
# Out:
# (464, 11)

# %%
ml1original_high.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# ### 9.Which action game has the highest global sales?

# %%
data_action = ml1original[ml1original['Genre'] == 'Action']

# %%
data_action
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# ...      ...                                                ...      ...
# 16564  16567      Original Frisbee Disc Sports: Ultimate & Golf       DS
# 16567  16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year   Genre                  Publisher  NA_Sales  EU_Sales  \
# ...

# %%
data_action.groupby('Global_Sales').max().sort_values('Global_Sales',ascending = False).head(1)
# Out:
#               Rank                Name Platform    Year   Genre  \
# Global_Sales
# 21.4            17  Grand Theft Auto V      PS3  2013.0  Action
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Global_Sales
# 21.4          Take-Two Interactive      7.01      9.27      0.97         4.14

# %% [markdown]
# ### 10. In which year the most games were released?

# %%
ml1original.mode()['Year'][0]
# Out:
# 2009.0

# %% [markdown]
# ### 11.Which platform had the most releases that year?

# %%
df_2009 = ml1[ml1['year']]
